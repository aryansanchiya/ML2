# %% [markdown]
# # Probability  Mass Function:

# %% [markdown]
# <h6>Here's the PMF formula:
#     <br>
#
# <i>P(X=xi)=pi</i></h6>

# %% [markdown]
# <h6>In simpler terms, the PMF tells us the likelihood of each possible outcome of a random variable.
#
# Let's take an example to illustrate this. Suppose we have a fair six-sided die. The random variable XX represents the outcome of rolling the die.
#
#     The possible outcomes are x1=1, x2=2, x3=3, x4=4, x5=5, and x6=6.
#     Since the die is fair, each outcome has an equal probability of 1/6.
#
# So, the PMF for this scenario is:
#
# P(X=1)=1/6
# P(X=2)=1/6
# P(X=3)=1/6
# P(X=4)=1/6
# P(X=5)=1/6
# P(X=6)=1/6
# </h6>

# %% [markdown]
# # <h1>Probability Density Function</h1>

# %% [markdown]
# #
# Here's the PDF formula:
#
# f(x)
#
# Where:
#
#     f(x)is the probability density function.
#     xrepresents a specific value of the continuous random variable.
#
#
# In simpler terms, the PDF tells us the relative likelihood of different outcomes occurring for a continuous random variable within a certain range.
#
# Now, let's take an example to understand this better. Suppose we have a continuous random variable XX representing the height of students in a class. We can use a normal distribution (also known as a bell curve) to model the heights.
#
#
# The PDF of a normal distribution is given by the formula:
# ![image.png](attachment:image.png)
#
#
#
# μ is the mean (average) height of the students.
# σσ is the standard deviation, which measures the spread of heights around the mean.
# ee is the base of the natural logarithm (approximately equal to 2.71828).

# %% [markdown]
# # Cumulative Distribution Function

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# So, the CDF gives you the probability that the random variable XX is less than or equal to any given value xx.
#
#
# ![image-2.png](attachment:image-2.png)
#
# The CDF helps us understand how the probability accumulates across different values of a random variable, providing valuable insights into the behavior of the variable.

# %% [markdown]
# # Binomial Distribution

# %% [markdown]
# ![image.png](attachment:image.png)
#
# n simpler terms, the formula calculates the probability of getting exactly kk successes in nn independent trials, where each trial has a probability pp of success.
#
#
# ![image-2.png](attachment:image-2.png)

# %%
#Example 3.4.1 (P.No : 66)
#1.Probability that exactly 5 customers will return the items.

from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

# %%
stats.binom.pmf(5,20,0.1)
# Out:
# 0.031921361119954424

# %%
pmf_df = pd.DataFrame({'success': range(0,21),
                      'pmf': list(stats.binom.pmf(range(0,21),
                                                 20,0.1))})

sn.barplot(x = pmf_df.success, y = pmf_df.pmf)
plt.ylabel('pmf')
plt.xlabel("Number of items returned");

# %%
stats.binom.cdf(5,20,0.1)
# Out:
# 0.988746865835491

# %% [markdown]
# <h1>Poisson Distribution </h1>

# %% [markdown]
# <h6>What is Poisson Distribution?</h6>
# <h6>Ans:- The Poisson distribution is a probability distribution that helps us model the number of times an event occurs within a fixed interval of time or space<h6>
#
# <h6>-->It's particularly useful for events that happen independently and with a known constant average rate.<h6>

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# <h5>Parameters
#
#     λ (lambda): The average number of events in the given interval. It's the key parameter of the Poisson distribution.</h5>

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
#Number of calls arriving at call center : 10 calls per hour
#1)Calculate the probability that number of calls will be maximum 5:
stats.poisson.cdf(5,10)
# Out:
# 0.06708596287903189

# %%
#2)Calculate the probability that the number of calls over a 3 hour period will be exceeded 30:1-
1 - stats.poisson.cdf(30,30)
# Out:
# 0.45164848742208863

# %%
#Range(0,30) returns all values from 0 to 30 (excluding 30)
pmf_df = pd.DataFrame({'success':range(0,30), 'pmf':list(stats.poisson.pmf(range(0,30),10))})
sn.barplot(x=pmf_df.success,y=pmf_df.pmf)
plt.xlabel("Number of calls Received");

# %% [markdown]
# # <h1>Exponential Distribution

# %% [markdown]
# # <h5>Exponential Distribution is a single parameter continuous distrbution that is traditionally used for modeling time-to-failure of electronic components. The exponential distribution represents a process in which event occur continuously and independently at a constant average rate.

# %% [markdown]
# # ![image.png](attachment:image.png)
#
# where lambda = rate of occurence of the event.
# Mean of exponential distribution is given by 1/lambda.

# %%
#1) The probability that the system will fail before 1000 hours:

stats.expon.cdf(1000,
               loc=1/1000,
               scale=1000)
# Out:
# 0.6321201909489326

# %%
#2) Probability that it will not fail upto 2000 hours:
1 - stats.expon.cdf(2000,
               loc=1/1000,
               scale=1000)
# Out:
# 0.13533541857196352

# %%
#3) Calculate the time by which 10% system will falie. ppf(Percent Point Function)
stats.expon.ppf(.1,
               loc=1/1000,
               scale=1000)
# Out:
# 105.36151565782632

# %% [markdown]
# # Normal Distribution:

# %%
import pandas as pd
import numpy as np
import warnings

# %%
beml_df = pd.read_csv("BEML.csv")

# %%
beml_df[0:5]
# Out:
#          Date    Open     High      Low    Last    Close  \
# 0  2010-01-04  1121.0  1151.00  1121.00  1134.0  1135.60
# 1  2010-01-05  1146.8  1149.00  1128.75  1135.0  1134.60
# 2  2010-01-06  1140.0  1164.25  1130.05  1137.0  1139.60
# 3  2010-01-07  1142.0  1159.40  1119.20  1141.0  1144.15
# 4  2010-01-08  1156.0  1172.00  1140.00  1141.2  1144.05
#
#    Total Trade Quantity  Turnover (Lacs)
# 0              101651.0          1157.18
# 1               59504.0           676.47
# 2              128908.0          1482.84
# 3              117871.0          1352.98
# 4              170063.0          1971.42

# %%
glaxo_df = pd.read_csv('GLAXO.csv')

# %%
glaxo_df[0:5]
# Out:
#          Date     Open     High      Low    Last    Close  \
# 0  2010-01-04  1613.00  1629.10  1602.00  1629.0  1625.65
# 1  2010-01-05  1639.95  1639.95  1611.05  1620.0  1616.80
# 2  2010-01-06  1618.00  1644.00  1617.00  1639.0  1638.50
# 3  2010-01-07  1645.00  1654.00  1636.00  1648.0  1648.70
# 4  2010-01-08  1650.00  1650.00  1626.55  1640.0  1639.80
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                9365.0           151.74
# 1               38148.0           622.58
# 2               36519.0           595.09
# 3               12809.0           211.00
# 4               28035.0           459.11

# %%
beml_df = beml_df[['Date','Close']]

# %%
beml_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
glaxo_df = glaxo_df[['Date','Close']]

# %%
glaxo_df
# Out:
#             Date    Close
# 0     2010-01-04  1625.65
# 1     2010-01-05  1616.80
# 2     2010-01-06  1638.50
# 3     2010-01-07  1648.70
# 4     2010-01-08  1639.80
# ...          ...      ...
# 1734  2016-12-26  2723.50
# 1735  2016-12-27  2701.75
# 1736  2016-12-28  2702.15
# 1737  2016-12-29  2727.90
# 1738  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
glaxo_df = glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date']))

# %%
glaxo_df
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1625.65
# 2010-01-05  2010-01-05  1616.80
# 2010-01-06  2010-01-06  1638.50
# 2010-01-07  2010-01-07  1648.70
# 2010-01-08  2010-01-08  1639.80
# ...                ...      ...
# 2016-12-26  2016-12-26  2723.50
# 2016-12-27  2016-12-27  2701.75
# 2016-12-28  2016-12-28  2702.15
# 2016-12-29  2016-12-29  2727.90
# 2016-12-30  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
beml_df = beml_df.set_index(pd.DatetimeIndex(beml_df['Date']))

# %%
beml_df
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1135.60
# 2010-01-05  2010-01-05  1134.60
# 2010-01-06  2010-01-06  1139.60
# 2010-01-07  2010-01-07  1144.15
# 2010-01-08  2010-01-08  1144.05
# ...                ...      ...
# 2016-12-26  2016-12-26   950.25
# 2016-12-27  2016-12-27   975.70
# 2016-12-28  2016-12-28   974.40
# 2016-12-29  2016-12-29   986.05
# 2016-12-30  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
glaxo_df[0:5]
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1625.65
# 2010-01-05  2010-01-05  1616.80
# 2010-01-06  2010-01-06  1638.50
# 2010-01-07  2010-01-07  1648.70
# 2010-01-08  2010-01-08  1639.80

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
plt.plot(beml_df.Close)
plt.xlabel('Time')
plt.ylabel('Close')
# Out:
# Text(0, 0.5, 'Close')

# %%
plt.plot(glaxo_df.Close)
plt.xlabel("Time")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
tata_df = pd.read_csv('TATAMOTORS_BSE.csv')

# %%
tata_df[0:5]
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2020-10-01  135.699997  136.500000  132.600006  133.500000  133.500000
# 1  2020-10-05  137.000000  137.500000  132.050003  133.899994  133.899994
# 2  2020-10-06  137.800003  145.699997  135.899994  144.850006  144.850006
# 3  2020-10-07  144.100006  144.500000  139.800003  141.000000  141.000000
# 4  2020-10-08  142.800003  143.350006  139.649994  140.899994  140.899994
#
#        Volume
# 0   1674311.0
# 1   2800303.0
# 2  10190922.0
# 3   4032654.0
# 4   2491175.0

# %%
tata_df = tata_df[["Date","Close"]]

# %%
tata_df
# Out:
#            Date       Close
# 0    2020-10-01  133.500000
# 1    2020-10-05  133.899994
# 2    2020-10-06  144.850006
# 3    2020-10-07  141.000000
# 4    2020-10-08  140.899994
# ..          ...         ...
# 243  2021-09-24  317.950012
# 244  2021-09-27  331.549988
# 245  2021-09-28  329.250000
# 246  2021-09-29  330.350006
# 247  2021-09-30  333.200012
#
# [248 rows x 2 columns]

# %%
tata_df = tata_df.set_index(pd.DatetimeIndex(tata_df['Date']))

# %%
tata_df
# Out:
#                   Date       Close
# Date
# 2020-10-01  2020-10-01  133.500000
# 2020-10-05  2020-10-05  133.899994
# 2020-10-06  2020-10-06  144.850006
# 2020-10-07  2020-10-07  141.000000
# 2020-10-08  2020-10-08  140.899994
# ...                ...         ...
# 2021-09-24  2021-09-24  317.950012
# 2021-09-27  2021-09-27  331.549988
# 2021-09-28  2021-09-28  329.250000
# 2021-09-29  2021-09-29  330.350006
# 2021-09-30  2021-09-30  333.200012
#
# [248 rows x 2 columns]

# %%
plt.plot(tata_df.Close)
plt.xlabel("Time")
plt.ylabel("Close")
# Out:
# Text(0, 0.5, 'Close')

# %%
# 1)What is the expected daily rate of return of these stocks?

glaxo_df['gain'] = glaxo_df.Close.pct_change(periods=1)

# %%
glaxo_df[0:5]
# Out:
#                   Date    Close      gain
# Date
# 2010-01-04  2010-01-04  1625.65       NaN
# 2010-01-05  2010-01-05  1616.80 -0.005444
# 2010-01-06  2010-01-06  1638.50  0.013422
# 2010-01-07  2010-01-07  1648.70  0.006225
# 2010-01-08  2010-01-08  1639.80 -0.005398

# %%
beml_df['gain'] = beml_df.Close.pct_change(periods=1)

# %%
beml_df[0:5]
# Out:
#                   Date    Close      gain
# Date
# 2010-01-04  2010-01-04  1135.60       NaN
# 2010-01-05  2010-01-05  1134.60 -0.000881
# 2010-01-06  2010-01-06  1139.60  0.004407
# 2010-01-07  2010-01-07  1144.15  0.003993
# 2010-01-08  2010-01-08  1144.05 -0.000087

# %%
glaxo_df = glaxo_df.dropna()
beml_df = beml_df.dropna()

# %%
# plt.figure(figsize=(8,6));
plt.plot(glaxo_df.index,glaxo_df.gain);
plt.xlabel('Time')
plt.ylabel('gain')
# Out:
# Text(0, 0.5, 'gain')

# %%
sn.distplot(glaxo_df.gain, label="Glaxo")
sn.distplot(beml_df.gain, label = "BEML")
plt.xlabel('gain')
plt.ylabel("Density")
plt.legend()
# Out:
# /tmp/ipykernel_14860/2017522158.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(glaxo_df.gain, label="Glaxo")
# /tmp/ipykernel_14860/2017522158.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(beml_df.gain, label = "BEML")

# %% [markdown]
# # Mean and Variance In Normal Distribution:![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)#

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("Daily gain of Glaxo:")
print("----------------------------")
print("Mean: ", round(glaxo_df.gain.mean(), 4))
print("Standard Deviation: ", round(glaxo_df.gain.std(),4))
# Out:
# Daily gain of Glaxo:
# ----------------------------
# Mean:  0.0004
# Standard Deviation:  0.0134

# %%
print("Daily gain of BEML:")
print("------------------------------")
print("Mean: ", round(beml_df.gain.mean(),4))
print("Standard Deviation: ", round(beml_df.gain.std(),4))
# Out:
# Daily gain of BEML:
# ------------------------------
# Mean:  0.0003
# Standard Deviation:  0.0264

# %%
beml_df.gain.describe()
# Out:
# count    1738.000000
# mean        0.000271
# std         0.026431
# min        -0.133940
# 25%        -0.013736
# 50%        -0.001541
# 75%         0.011985
# max         0.198329
# Name: gain, dtype: float64

# %% [markdown]
# # Cumulative Probability Distribution:

# %%
#PROBABILITY THAT LOSS WILL BE MORE THAN 2%
print("Proba. of making 2% loss or more: ")
stats.norm.cdf(-0.02,
              loc=glaxo_df.gain.mean(),
              scale=glaxo_df.gain.std())
# Out:
# Proba. of making 2% loss or more:
# 0.06352488667177397

# %%
print("Proba. of making 2% loss or more: ")
stats.norm.cdf(-0.02,
              loc=beml_df.gain.mean(),
              scale=beml_df.gain.std())
# Out:
# Proba. of making 2% loss or more:
# 0.22155987503755287

# %%
#WHICH STOCK HAS HIGHER PRIORITY OF MAKING A DAILY RETURN OF 2% OR MORE
print("Proba. of making 2% PROFIT or more OF GLAXO: ",
1 - stats.norm.cdf(0.02,
              loc=glaxo_df.gain.mean(),
              scale=glaxo_df.gain.std()))
# Out:
# Proba. of making 2% PROFIT or more OF GLAXO:  0.07104511457618568

# %%
print("Proba. of making 2% PROFIT or more OF BEML: ",
1 - stats.norm.cdf(0.02,
              loc=beml_df.gain.mean(),
              scale=beml_df.gain.std()))
# Out:
# Proba. of making 2% PROFIT or more OF BEML:  0.22769829484075355

# %% [markdown]
# # Null Hypothesis:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Difference between "Population Mean" & "Sample Mean":
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# # Z-test
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %%
# Example : 1 Page No: 82
# -A Passport application procesed within 30 days of submitting the application form and all necessary documents
# File : passport.csv (Processing time of 40 passports)
# Population standard deviation of the processing time : 12.5


passport_df = pd.read_csv("passport.csv")

# %%
passport_df[0:5]
# Out:
#    processing_time
# 0             16.0
# 1             16.0
# 2             30.0
# 3             37.0
# 4             25.0

# %%
print(list(passport_df.processing_time))
# Out:
# [16.0, 16.0, 30.0, 37.0, 25.0, 22.0, 19.0, 35.0, 27.0, 32.0, 34.0, 28.0, 24.0, 35.0, 24.0, 21.0, 32.0, 29.0, 24.0, 35.0, 28.0, 29.0, 18.0, 31.0, 28.0, 33.0, 32.0, 24.0, 25.0, 22.0, 21.0, 27.0, 41.0, 23.0, 23.0, 16.0, 24.0, 38.0, 26.0, 28.0]

# %%
import math

# %%
def z_test(pop_mean, pop_std, sample):
    z_score = (sample.mean()-pop_mean)/(pop_std/math.sqrt(len(sample)))
    return z_score, stats.norm.cdf(z_score)

# %%
z_test(30,12.5,passport_df.processing_time)
# Out:
# (-1.4925950555994747, 0.06777160919961511)

# %% [markdown]
# # T-Test

# %%
#When We dont know about population standard deviation at that time we can use T-Test.

# %%
# Formula
# (Sample_mean-Population_Mean)/(Population_Std_Deviation/sqrroot_of_sample_length)

# Note: The expected value (mean) of a sample of independent observation is equal to the given population mean.

# %%
bollywood_movies_df = pd.read_csv('bollywoodmovies.csv')

# %%
bollywood_movies_df.head(5)
# Out:
#    production_cost
# 0              601
# 1              627
# 2              330
# 3              364
# 4              562

# %%
print(list(bollywood_movies_df.production_cost))
# Out:
# [601, 627, 330, 364, 562, 353, 583, 254, 528, 470, 125, 60, 101, 110, 60, 252, 281, 227, 484, 402, 408, 601, 593, 729, 402, 530, 708, 599, 439, 762, 292, 636, 444, 286, 636, 667, 252, 335, 457, 632]

# %%
stats.ttest_1samp(bollywood_movies_df.production_cost, 500)
# Out:
# TtestResult(statistic=-2.2845532872667547, pvalue=0.027862556406761777, df=39)

# %% [markdown]
# # Two Sample T-Test

# %%
# Question on P.no : 85

# %%
healthdrink_yes_df = pd.read_excel('healthdrink.xlsx','healthdrink_yes')

# %%
healthdrink_yes_df
# Out:
#     height_increase
# 0               8.6
# 1               5.8
# 2              10.2
# 3               8.5
# 4               6.8
# ..              ...
# 74              6.5
# 75              8.1
# 76              7.2
# 77              8.8
# 78              9.8
#
# [79 rows x 1 columns]

# %%
healthdrink_yes_df.columns
# Out:
# Index(['height_increase'], dtype='object')

# %%
healthdrink_no_df = pd.read_excel('healthdrink.xlsx', 'healthdrink_no')

# %%
healthdrink_no_df
# Out:
#     height_increase
# 0               5.3
# 1               9.0
# 2               5.7
# 3               5.5
# 4               5.4
# ..              ...
# 75              4.4
# 76              5.3
# 77              6.2
# 78              7.4
# 79              4.2
#
# [80 rows x 1 columns]

# %%
sn.distplot(healthdrink_yes_df['height_increase'], label='healthdrink_yes') 
sn.distplot(healthdrink_no_df['height_increase'], label = 'healthdrink_no')
plt.legend();
# Out:
# /tmp/ipykernel_14860/2815980878.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(healthdrink_yes_df['height_increase'], label='healthdrink_yes')
# /tmp/ipykernel_14860/2815980878.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
stats.ttest_ind(healthdrink_yes_df['height_increase'],
               healthdrink_no_df['height_increase'])
# Out:
# TtestResult(statistic=8.131675069083359, pvalue=1.197698592263946e-13, df=157.0)
